# %%
##  基础函数库
import numpy as np 
import pandas as pd

## 绘图函数库
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## 我们利用 sklearn 中自带的 iris 数据作为数据载入，并利用Pandas转化为DataFrame格式
from sklearn.datasets import load_iris
data = pd.read_csv('data.csv')
iris_target = data.version #得到数据对应的标签
iris_features = data.drop('version',axis=1) #得到数据对应的特征

# %%
## 利用.info()查看数据的整体信息
iris_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  34 non-null     int64
#  1   feature1    34 non-null     float64
#  2   feature2    34 non-null     float64
#  3   feature3    34 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 1.2 KB

# %%
## 进行简单的数据查看，我们可以利用 .head() 头部.tail()尾部
iris_features.head()
# Out:
#    Unnamed: 0  feature1  feature2  feature3
# 0           0 -3.110400  0.165876 -0.809430
# 1           1 -3.110400  0.165876 -0.809430
# 2           2 -3.235343  0.316533 -0.723929
# 3           3 -2.955469  0.227415 -0.730198
# 4           4 -2.955469  0.227415 -0.730198

# %%
iris_features.tail()
# Out:
#     Unnamed: 0  feature1  feature2  feature3
# 29          12  2.826361 -0.802756 -0.386310
# 30          13  2.807528 -0.786319 -0.420702
# 31          14  2.989352 -0.880862 -0.357100
# 32          15  2.970519 -0.864425 -0.391493
# 33          16  4.267422 -1.056668  1.683568

# %%
## 合并标签和特征信息
iris_all = iris_features.copy() ##进行浅拷贝，防止对于原始数据的修改
iris_all['target'] = iris_target
## 特征与标签组合的散点可视化
sns.pairplot(data=iris_all,diag_kind='hist', hue= 'target')
plt.show()
